# %%
import joblib as jb
import os

# %%
file=os.path.expanduser("~/Desktop/Project/spam_email/Model/model.joblib")
model=jb.load(file)

# %%
email=input("Enter the email text here:")
# Out:
# Enter the email text here: discount discount discount discount discount discount discount discount

# %%
a=model.predict([email])
if a[0]==0:
    print("It's a ham email")
else:
    print("It's a spam email")
# Out:
# It's a ham email
