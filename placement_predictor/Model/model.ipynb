# %%
import joblib as jb
import os
import warnings
warnings.filterwarnings('ignore')

# %%
file=os.path.expanduser('C:/Users/Thirtesh/Desktop/Project/placement_predictor/Model/model.joblib')
model=jb.load(file)

# %%
cgpa=float(input('Enter your CGPA:'))
p=int(input('Enter the number of major projects:'))
wc=int(input('Enter the number of workshops/certifications:'))
mp=int(input('Enter the number of mini Projects:'))
skills=int(input('Enter the number of skills:'))
csr=float(input('Enter your communication skill rating(out of 5):'))
i=str(input('Do you have an internship:')).lower()
h=str(input('Have you participated in any hackatons:')).lower()
p12=int(input('Enter your 12th percentage:'))
p10=int(input('Enter your 10th percentage:'))
b=int(input('Enter the number of backlogs:'))
# Out:
# Enter your CGPA: 8.5
# Enter the number of major projects: 3
# Enter the number of workshops/certifications: 0
# Enter the number of mini Projects: 10
# Enter the number of skills: 8
# Enter your communication skill rating(out of 5): 4.0
# Do you have an internship: yes
# Have you participated in any hackatons: no
# Enter your 12th percentage: 89
# Enter your 10th percentage: 91
# Enter the number of backlogs: 0

# %%
i=1 if i=='yes' else 0
h=1 if h=='yes' else 0

# %%
model.predict([(cgpa, p, wc, mp, skills, csr, i, h, p12, p10, b)])
# Out:
# array([1])
