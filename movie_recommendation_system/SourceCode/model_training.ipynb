# %%
import sklearn as sk
import pandas as pd

# %%
file='~/Desktop/Project/movie_recommendation_system/Dataset/movies.csv'
data=pd.read_csv(file)
data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   str
#  2   genres   9742 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 626.1 KB

# %%
data.nunique()
# Out:
# movieId    9742
# title      9737
# genres      951
# dtype: int64

# %%
tfidf=sk.feature_extraction.text.TfidfVectorizer()
tfidf_matrix=tfidf.fit_transform(data['genres'])

# %%
import joblib as jb
import os

# %%
file=os.path.expanduser('~/Desktop/Project/movie_recommendation_system/Model/tfidf_matrix.joblib')
jb.dump(tfidf_matrix, file)
# Out:
# ['C:\\Users\\Thirtesh/Desktop/Project/movie_recommendation_system/Model/tfidf_matrix.joblib']
