# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style
import sklearn as sk

# %%
df=pd.DataFrame(pd.read_csv('~/Desktop/Project/wine_quality/Dataset/winequality-white.csv',sep=';'))
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
style.use('ggplot')
sns.countplot(x='quality', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
plt.figure(figsize=(2,6))
sns.heatmap(df.drop(['quality'],axis=1).corrwith(df['quality']).sort_values(ascending=False).to_frame(), annot=True)
# Out:
# <Axes: >

# %%
df['quality']=df.quality.apply(lambda x: 1 if x>=7 else 0)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        0
# 1      9.5        0
# 2     10.1        0
# ...

# %%
X_train, X_test, y_train, y_test= sk.model_selection.train_test_split(df.drop('quality',axis=1), df['quality'],test_size=0.2, random_state=77)

# %%
X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3778            6.3              0.15         0.30            1.40      0.022
# 4638            6.5              0.51         0.25            1.70      0.048
# 3995            8.0              0.37         0.31            4.70      0.038
# 3496            6.0              0.24         0.28            3.95      0.038
# 3468            6.6              0.16         0.36            1.10      0.031
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3778                 38.0                 100.0  0.99099  3.42       0.57
# 4638                 39.0                 177.0  0.99212  3.28       0.57
# 3995                  3.0                 127.0  0.99186  2.90       0.72
# 3496                 61.0                 134.0  0.99146  3.30       0.54
# 3468                 27.0                  93.0  0.98884  3.23       0.34
#
#       alcohol
# 3778     11.4
# 4638     10.6
# ...

# %%
RandFor = sk.ensemble.RandomForestClassifier(n_estimators=180,n_jobs=-1)
RandFor.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
params={'max_depth':[70,100, 150], 'criterion':['gini','entropy']}

# %%
grid=sk.model_selection.RandomizedSearchCV(RandFor, param_distributions=params, scoring='precision',cv=3, n_iter=6)

# %%
grid.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(n_jobs=-1), n_iter=6,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [70, 100, 150]},
#                    scoring='precision')

# %%
pre=grid.predict(X_test)

# %%
print(sk.metrics.accuracy_score(y_test,pre))
print(sk.metrics.precision_score(y_test,pre))
# Out:
# 0.8693877551020408
# 0.8175182481751825

# %%
import joblib as jb
file='C:/Users/Thirtesh/Desktop/Project/wine_quality/Model/model.joblib'
jb.dump(grid,file)
# Out:
# ['C:/Users/Thirtesh/Desktop/Project/wine_quality/Model/model.joblib']
